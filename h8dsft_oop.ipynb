# %%
class Book:
    def __init__(self, title, author, identifier):
        self.title = title
        self.author = author
        self.identifier = identifier

    def __str__(self):
        return f"Title: {self.title}, Author: {self.author}, Identifier: {self.identifier}"

class LibraryCatalog:
    def __init__(self):
        self.catalog = {}

    def add_book(self, book):
        if book.identifier not in self.catalog:
            self.catalog[book.identifier] = book
            print("Book added successfully.")
        else:
            print("A book with the same identifier already exists.")

    def search_book(self, keyword):
        found_books = []
        for book in self.catalog.values():
            if keyword.lower() in book.title.lower() or keyword.lower() in book.author.lower():
                found_books.append(book)
        if found_books:
            for book in found_books:
                print(book)
        else:
            print("No books found with the given keyword.")

    def remove_book(self, identifier):
        if identifier in self.catalog:
            del self.catalog[identifier]
            print("Book removed successfully.")
        else:
            print("Book not found.")

    def display_all_books(self):
        if self.catalog:
            for book in self.catalog.values():
                print(book)
        else:
            print("No books in the catalog.")

# Testing the Library Catalog
library = LibraryCatalog()

while True:
    print("\nLibrary Catalog Menu:")
    print("1. Add a book")
    print("2. Search for a book")
    print("3. Remove a book")
    print("4. Display all books")
    print("5. Exit")
    
    choice = input("Enter your choice: ")

    if choice == '1':
        title = input("Enter the title of the book: ")
        author = input("Enter the author of the book: ")
        identifier = input("Enter the unique identifier of the book: ")
        book = Book(title, author, identifier)
        library.add_book(book)
    
    elif choice == '2':
        keyword = input("Enter title or author keyword to search: ")
        library.search_book(keyword)
    
    elif choice == '3':
        identifier = input("Enter the identifier of the book to remove: ")
        library.remove_book(identifier)
    
    elif choice == '4':
        library.display_all_books()
    
    elif choice == '5':
        print("Exiting the program...")
        break
    
    else:
        print("Invalid choice. Please enter a valid option.")
# Out:
# Library Catalog Menu:
# 1. Add a book
# 2. Search for a book
# 3. Remove a book
# 4. Display all books
# 5. Exit
# Book added successfully.
#
# Library Catalog Menu:
# 1. Add a book
# 2. Search for a book
# 3. Remove a book
# 4. Display all books
# 5. Exit
# Title: ada, Author: ada, Identifier: ada
#
# Library Catalog Menu:
# 1. Add a book
# 2. Search for a book
# 3. Remove a book
# 4. Display all books
# 5. Exit
# Exiting the program...
